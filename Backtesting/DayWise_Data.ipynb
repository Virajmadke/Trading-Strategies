# %%
import pandas as pd
import numpy as np
import time as TIME
import datetime as dt
from datetime import date
from datetime import timedelta
import math
import os

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('fno_stocks.xlsx', header= 1)
Tickers = (df["Symbol"])
Tickers = Tickers.astype(str)

Tickers = Tickers.drop(Tickers[Tickers.values == "BANKNIFTY"].index.values[0], axis =0)
Tickers = Tickers.drop(Tickers[Tickers.values == "NIFTY"].index.values[0], axis =0)
Tickers = Tickers.reset_index(drop = True)
Tickers
# Out:
# 0            IDEA
# 1      COROMANDEL
# 2            ZEEL
# 3       NESTLEIND
# 4        ASHOKLEY
#           ...
# 167    APOLLOHOSP
# 168        INDIGO
# 169    CANFINHOME
# 170    ICICIPRULI
# 171       SBILIFE
# Name: Symbol, Length: 172, dtype: object

# %%
# %%time
weekDays = ("Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday")
Daily_pct_change = pd.DataFrame()
current_date = date(2017,1,1)
current_date = pd.Timestamp(current_date, tz =19800)
#todays_date = dt.datetime.now().date()
todays_date  = date(2021,9,23)
flag = 0
#Loop from start date till today
while(current_date <= todays_date):
    #Calculating daily pct change for all stocks till 10 Am
    
    start = dt.datetime.now()
    pct_change = {}
    Daily_pct_change = pd.read_csv("Day_Wise_Stats.csv", index_col = 0,  parse_dates = [2])
    if(flag==0):
        current_date = Daily_pct_change.Date.iloc[-1] + timedelta(days =1)
        flag = 1
        if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
    
    if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
    
    print(str(current_date) + " : Started")
    for ticker in Tickers:
        daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [1])
        daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1)]
        daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
        daily_data = daily_data.reset_index(drop = True)
        if(daily_data.empty == True):
            continue
        change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 60)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
        pct_change[ticker] = change_value
    
    if(bool(pct_change) == False):
        print("Today is a Market Holiday")
        current_date = current_date + timedelta(days =1)
        continue
        
    top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
    change = pd.DataFrame()
    change["Tickers"] = top_gainers.keys()
    change["PCT_Change"] = top_gainers.values()
    if(change.empty == True):
        print(str(current_date) + " : Finished") 
        continue
        
    gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
    loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
    ad_ratio    = gain_number/loss_number
    end = dt.datetime.now() - start
    print("Time Required to calculate pct change: " + str(end)) 
    print("PCT Change Calculated!")
    for i in range(5):
        print(change["Tickers"][i])
    new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
    Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
    Daily_pct_change.to_csv("Day_Wise_Stats.csv")
    
    #date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
    ##date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    #date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
    #index = date_data[date_data.date <= current_date + timedelta(minutes  = 370)].index[-1]
    #date_data = date_data[:index + 2]
    ##date_data = date_data.reset_index(drop = True)
    print(str(current_date) + " : Finished") 
    current_date = current_date + timedelta(days =1)
# Out:
# 2018-11-10 09:15:00+05:30 : Started
# 2018-11-10 09:15:00+05:30 : Finished
# 2018-11-11 09:15:00+05:30 : Started
# 2018-11-11 09:15:00+05:30 : Finished
# 2018-11-12 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:20.395027
# PCT Change Calculated!
# CUMMINSIND
# MPHASIS
# BPCL
# TECHM
# HCLTECH
# 2018-11-12 09:15:00+05:30 : Finished
# 2018-11-13 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:21.302042
# PCT Change Calculated!
# IPCALAB
# TORNTPHARM
# EICHERMOT
# TRENT
# JUBLFOOD
# 2018-11-13 09:15:00+05:30 : Finished
# 2018-11-14 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:20.324052
# PCT Change Calculated!
# BPCL
# HINDPETRO
# IOC
# CUMMINSIND
# ASTRAL
# 2018-11-14 09:15:00+05:30 : Finished
# 2018-11-15 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:21.258046
# PCT Change Calculated!
# SIEMENS
# MFSL
# AUBANK
# ADANIENT
# ADANIPORTS
# 2018-11-15 09:15:00+05:30 : Finished
# 2018-11-16 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:20.565119
# PCT Change Calculated!
# MOTHERSUMI
# BHARTIARTL
# BANDHANBNK
# PAGEIND
# OFSS
# 2018-11-16 09:15:00+05:30 : Finished
# 2018-11-17 09:15:00+05:30 : Started
# 2018-11-17 09:15:00+05:30 : Finished
# 2018-11-18 09:15:00+05:30 : Started
# 2018-11-18 09:15:00+05:30 : Finished
# 2018-11-19 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:21.222001
# PCT Change Calculated!
# IDEA
# GRASIM
# DLF
# RECLTD
# NATIONALUM
# 2018-11-19 09:15:00+05:30 : Finished
# 2018-11-20 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:18.997481
# PCT Change Calculated!
# PFC
# DEEPAKNTR
# LICHSGFIN
# PNB
# LALPATHLAB
# 2018-11-20 09:15:00+05:30 : Finished
# 2018-11-21 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:19.665121
# PCT Change Calculated!
# EXIDEIND
# DLF
# LICHSGFIN
# TVSMOTOR
# JSWSTEEL
# 2018-11-21 09:15:00+05:30 : Finished
# 2018-11-22 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:20.266018
# PCT Change Calculated!
# IDEA
# INDHOTEL
# TORNTPOWER
# IPCALAB
# ADANIPORTS
# 2018-11-22 09:15:00+05:30 : Finished
# 2018-11-23 09:15:00+05:30 : Started
# Today is a Market Holiday
# 2018-11-24 09:15:00+05:30 : Started
# 2018-11-24 09:15:00+05:30 : Finished
# 2018-11-25 09:15:00+05:30 : Started
# 2018-11-25 09:15:00+05:30 : Finished
# 2018-11-26 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.525944
# PCT Change Calculated!
# PFC
# NAM-INDIA
# RECLTD
# BHEL
# AUBANK
# 2018-11-26 09:15:00+05:30 : Finished
# 2018-11-27 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:25.485946
# PCT Change Calculated!
# BANDHANBNK
# NAUKRI
# COLPAL
# TRENT
# CANBK
# 2018-11-27 09:15:00+05:30 : Finished
# 2018-11-28 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:20.732647
# PCT Change Calculated!
# LTTS
# MFSL
# CANFINHOME
# TORNTPHARM
# L&TFH
# 2018-11-28 09:15:00+05:30 : Finished
# 2018-11-29 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03
09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:45.423529
# PCT Change Calculated!
# DIXON
# CHOLAFIN
# DLF
# SRTRANSFIN
# AMBUJACEM
# 2018-12-19 09:15:00+05:30 : Finished
# 2018-12-20 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:40.758989
# PCT Change Calculated!
# LICHSGFIN
# DIXON
# BALKRISIND
# JUBLFOOD
# CUB
# 2018-12-20 09:15:00+05:30 : Finished
# 2018-12-21 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:59.215091
# PCT Change Calculated!
# CUB
# TATACONSUM
# DIXON
# HDFCBANK
# NATIONALUM
# 2018-12-21 09:15:00+05:30 : Finished
# 2018-12-22 09:15:00+05:30 : Started
# 2018-12-22 09:15:00+05:30 : Finished
# 2018-12-23 09:15:00+05:30 : Started
# 2018-12-23 09:15:00+05:30 : Finished
# 2018-12-24 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:25.304568
# PCT Change Calculated!
# MPHASIS
# L&TFH
# TATACONSUM
# UPL
# MUTHOOTFIN
# 2018-12-24 09:15:00+05:30 : Finished
# 2018-12-25 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:36.416196
# PCT Change Calculated!
# ZEEL
# COROMANDEL
# DABUR
# INDHOTEL
# ICICIGI
# 2018-12-25 09:15:00+05:30 : Finished
# 2018-12-26 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:58.700428
# PCT Change Calculated!
# ZEEL
# COROMANDEL
# DABUR
# INDHOTEL
# ICICIGI
# 2018-12-26 09:15:00+05:30 : Finished
# 2018-12-27 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:58.066118
# PCT Change Calculated!
# SBILIFE
# RECLTD
# HDFCLIFE
# COFORGE
# INFY
# 2018-12-27 09:15:00+05:30 : Finished
# 2018-12-28 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:58.249357
# PCT Change Calculated!
# SAIL
# MANAPPURAM
# BALKRISIND
# NAM-INDIA
# JUBLFOOD
# 2018-12-28 09:15:00+05:30 : Finished
# 2018-12-29 09:15:00+05:30 : Started
# 2018-12-29 09:15:00+05:30 : Finished
# 2018-12-30 09:15:00+05:30 : Started
# 2018-12-30 09:15:00+05:30 : Finished
# 2018-12-31 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:55.227408
# PCT Change Calculated!
# CONCOR
# NMDC
# MOTHERSUMI
# TATASTEEL
# LTTS
# 2018-12-31 09:15:00+05:30 : Finished
# 2019-01-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:59.039312
# PCT Change Calculated!
# GODREJPROP
# IGL
# GRANULES
# SUNPHARMA
# DLF
# 2019-01-01 09:15:00+05:30 : Finished
# 2019-01-02 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:00.355734
# PCT Change Calculated!
# ALKEM
# HAL
# LTI
# BHEL
# PIDILITIND
# 2019-01-02 09:15:00+05:30 : Finished
# 2019-01-03 09:15:00+05:30 : Started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2136             data = {k: v for k, (i, v) in zip(names, data)}
#    2137
# -> 2138             names, data = self._do_date_conversions(names, data)
#    2139             index, names = self._make_index(data, alldata, names)
#    2140
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _do_date_conversions(self, names, data)
#    1837
#    1838         if self.parse_dates is not None:
# -> 1839             data, names = _process_date_conversion(
#    1840                 data,
#    1841                 self._date_conv,
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3375                 if _isindex(colspec):
#    3376                     continue
# -> 3377                 data_dict[colspec] = converter(data_dict[colspec])
#    3378             else:
#    3379                 new_name, col, old_names = _try_convert_dates(
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3305
#    3306             try:
# -> 3307                 return tools.to_datetime(
#    3308                     ensure_object(strs),
#    3309                     utc=None,
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     828             result = _convert_and_box_cache(arg, cache_array)
#     829         else:
# --> 830             result = convert_listlike(arg, format)
#     831     else:
#     832         result = convert_listlike(np.array([arg]), format)[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     463         assert format is None or infer_datetime_format
#     464         utc = tz == "utc"
# --> 465         result, tz_parsed = objects_to_datetime64ns(
#     466             arg,
#     467             dayfirst=dayfirst,
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2073
#    2074     try:
# -> 2075         result, tz_parsed = tslib.array_to_datetime(
#    2076             data,
#    2077             errors=errors,
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\anaconda3\lib\site-packages\pytz\__init__.py in FixedOffset(offset, _tzinfos)
#     492         return UTC
#     493
# --> 494     info = _tzinfos.get(offset)
#     495     if info is None:
#     496         # We haven't seen this one before. we need to save it.
#
# KeyboardInterrupt:

# %%
# Out:
# Timestamp('2018-11-07 09:15:00+0530', tz='pytz.FixedOffset(330)')

# %%
current_date = date(2017,1,2)
current_date = pd.Timestamp(current_date, tz =19800)
Daily_pct_change = pd.DataFrame()
#todays_date = dt.datetime.now().date()
todays_date  = date(2021,9,23)
pct_change = {}
start = dt.datetime.now()
print(str(current_date) + " : Started")
for ticker in Tickers:
    daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [2])
    daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
    daily_data = daily_data.reset_index(drop = True)
    if(daily_data.empty == True):
        continue
    change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 60)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
    pct_change[ticker] = change_value
    #rint(change_value)

top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
change = pd.DataFrame()
change["Tickers"] = top_gainers.keys()
change["PCT_Change"] = top_gainers.values()
gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
ad_ratio    = gain_number/loss_number
end = dt.datetime.now() - start
print("Time Required to calculate pct change: " + str(end)) 
print("PCT Change Calculated!")
for i in range(5):
    print(change["Tickers"][i])
    
new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
Daily_pct_change.to_csv("Day_Wise_Stats.csv")

date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
date_data = date_data.reset_index(drop = True)
current_date = date_data.date.iloc[-1]
print(str(current_date) + " : Finished")
# Out:
# 2017-01-02 00:00:00+05:30 : Started
# Time Required to calculate pct change: 0:03:44.616232
# PCT Change Calculated!
# BHARATFORG
# ASTRAL
# MOTHERSUMI
# PETRONET
# BHEL
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8fefa14b1ece> in <module>
#      32
#      33 new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
# ---> 34 Daily_pct_change = Daily_pct_change.append(new_row_daily, ignore_index = True )
#      35 Daily_pct_change.to_csv("Day_Wise_Stats.csv")
#      36 print(str(current_date) + " : Finished")
#
# NameError: name 'new_row_daily' is not defined

# %%
import pandas as pd
import numpy as np
import time as TIME
import datetime as dt
from datetime import date
from datetime import timedelta
import math
import os

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('fno_stocks.xlsx', header= 1)
Tickers = (df["Symbol"])
Tickers = Tickers.astype(str)

Tickers = Tickers.drop(Tickers[Tickers.values == "BANKNIFTY"].index.values[0], axis =0)
Tickers = Tickers.drop(Tickers[Tickers.values == "NIFTY"].index.values[0], axis =0)
Tickers = Tickers.reset_index(drop = True)
Tickers
# Out:
# 0            IDEA
# 1      COROMANDEL
# 2            ZEEL
# 3       NESTLEIND
# 4        ASHOKLEY
#           ...
# 167    APOLLOHOSP
# 168        INDIGO
# 169    CANFINHOME
# 170    ICICIPRULI
# 171       SBILIFE
# Name: Symbol, Length: 172, dtype: object

# %%
# %%time
weekDays = ("Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday")
Daily_pct_change = pd.DataFrame()
current_date = date(2017,1,1)
current_date = pd.Timestamp(current_date, tz =19800)
#todays_date = dt.datetime.now().date()
todays_date  = date(2021,5,1)
flag = 0
#Loop from start date till today
while(current_date <= todays_date):
    #Calculating daily pct change for all stocks till 10 Am
    
    start = dt.datetime.now()
    pct_change = {}
    Daily_pct_change = pd.read_csv("New Folder/" + "Day_Wise_Stats_2021.csv", index_col = 0,  parse_dates = [2])
    if(flag==0):
        current_date = Daily_pct_change.Date.iloc[-1] + timedelta(days =1)
        flag = 1
        if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
                
    if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
    
    print(str(current_date) + " : Started")
    for ticker in Tickers:
        daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [1])
        daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
        daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
        daily_data = daily_data.reset_index(drop = True)
        if(daily_data.empty == True):
            continue
        change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 60)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
        pct_change[ticker] = change_value
    
    if(bool(pct_change) == False):
        print("Today is a Market Holiday")
        current_date = current_date + timedelta(days =1)
        continue
    
    top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
    change = pd.DataFrame()
    change["Tickers"] = top_gainers.keys()
    change["PCT_Change"] = top_gainers.values()
    if(change.empty == True):
        print(str(current_date) + " : Finished") 
        continue
        
    gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
    loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
    ad_ratio    = gain_number/loss_number
    end = dt.datetime.now() - start
    print("Time Required to calculate pct change: " + str(end)) 
    print("PCT Change Calculated!")
    for i in range(5):
        print(change["Tickers"][i])
    new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
    Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
    Daily_pct_change.to_csv("New Folder/" + "Day_Wise_Stats_2021.csv")
    
    #date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
    ##date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    #date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
    #index = date_data[date_data.date <= current_date + timedelta(minutes  = 370)].index[-1]
    #date_data = date_data[:index + 2]
    ##date_data = date_data.reset_index(drop = True)
    print(str(current_date) + " : Finished")
    current_date = current_date + timedelta(days =1)
# Out:
# 2021-01-27 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:58.322521
# PCT Change Calculated!
# GUJGASLTD
# LTI
# LTTS
# GRASIM
# ASHOKLEY
# 2021-01-27 09:15:00+05:30 : Finished
# 2021-01-28 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:47.000104
# PCT Change Calculated!
# DEEPAKNTR
# BANDHANBNK
# IDEA
# AXISBANK
# DLF
# 2021-01-28 09:15:00+05:30 : Finished
# 2021-01-29 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:41.484600
# PCT Change Calculated!
# SRTRANSFIN
# BEL
# COLPAL
# CONCOR
# M&M
# 2021-01-29 09:15:00+05:30 : Finished
# 2021-01-30 09:15:00+05:30 : Started
# 2021-01-30 09:15:00+05:30 : Finished
# 2021-01-31 09:15:00+05:30 : Started
# 2021-01-31 09:15:00+05:30 : Finished
# 2021-02-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:40.387814
# PCT Change Calculated!
# CIPLA
# METROPOLIS
# PVR
# TATACHEM
# CUMMINSIND
# 2021-02-01 09:15:00+05:30 : Finished
# 2021-02-02 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:43.324886
# PCT Change Calculated!
# INDIAMART
# HDFCBANK
# HDFC
# ULTRACEMCO
# STAR
# 2021-02-02 09:15:00+05:30 : Finished
# 2021-02-03 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:42.694144
# PCT Change Calculated!
# INDUSINDBK
# RBLBANK
# ESCORTS
# GUJGASLTD
# SRTRANSFIN
# 2021-02-03 09:15:00+05:30 : Finished
# 2021-02-04 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:35.185374
# PCT Change Calculated!
# APOLLOTYRE
# MANAPPURAM
# BALKRISIND
# DLF
# INDIAMART
# 2021-02-04 09:15:00+05:30 : Finished
# 2021-02-05 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:40.692752
# PCT Change Calculated!
# GODREJPROP
# SBIN
# DIXON
# KOTAKBANK
# HDFCBANK
# 2021-02-05 09:15:00+05:30 : Finished
# 2021-02-06 09:15:00+05:30 : Started
# 2021-02-06 09:15:00+05:30 : Finished
# 2021-02-07 09:15:00+05:30 : Started
# 2021-02-07 09:15:00+05:30 : Finished
# 2021-02-08 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:55.851092
# PCT Change Calculated!
# CONCOR
# EXIDEIND
# TITAN
# HAL
# AUBANK
# 2021-02-08 09:15:00+05:30 : Finished
# 2021-02-09 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:53.499163
# PCT Change Calculated!
# INDUSTOWER
# IDEA
# AARTIIND
# INDIAMART
# PNB
# 2021-02-09 09:15:00+05:30 : Finished
# 2021-02-10 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:55.421012
# PCT Change Calculated!
# NAUKRI
# MFSL
# MUTHOOTFIN
# DIXON
# M&MFIN
# 2021-02-10 09:15:00+05:30 : Finished
# 2021-02-11 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:53.069066
# PCT Change Calculated!
# NAVINFLUOR
# MGL
# IDEA
# CONCOR
# HINDALCO
# 2021-02-11 09:15:00+05:30 : Finished
# 2021-02-12 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:47.981147
# PCT Change Calculated!
# ASHOKLEY
# MRF
# MUTHOOTFIN
# M&MFIN
# CANFINHOME
# 2021-02-12 09:15:00+05:30 : Finished
# 2021-02-13 09:15:00+05:30 : Started
# 2021-02-13 09:15:00+05:30 : Finished
# 2021-02-14 09:15:00+05:30 : Started
# 2021-02-14 09:15:00+05:30 : Finished
# 2021-02-15 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:53.941530
# PCT Change Calculated!
# M&MFIN
# CHOLAFIN
# DEEPAKNTR
# SRTRANSFIN
# L&TFH
# 2021-02-15 09:15:00+05:30 : Finished
# 2021-02-16 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:51.640682
# PCT Change Calculated!
# JINDALSTEL
# SAIL
# TATASTEEL
# JSWSTEEL
# HINDALCO
# 2021-02-16 09:15:00+05:30 : Finished
# 2021-02-17 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:54.402720
# PCT Change Calculated!
# PNB
# MUTHOOTFIN
# PAGEIND
# CONCOR
# BANKBARODA
# 2021-02-17 09:15:00+05:30 : Finished
# 2021-02-18 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:52.132420
# PCT Change Calculated!
# GUJGASLTD
# IGL
# MGL
# SAIL
# POWERGRID
# 2021-02-18 09:15:00+05:30 : Finished
# 2021-02-19 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:54.660346
# PCT Change Calculated!
# IDFCFIRSTB
# RBLBANK
# TATACHEM
# CONCOR
# INDUSINDBK
# 2021-02-19 09:15:00+05:30 : Finished
# 2021-02-20 09:15:00+05:30 : Started
# 2021-02-20 09:15:00+05:30 : Finished
# 2021-02-21 09:15:00+05:30 : Started
# 2021-02-21 09:15:00+05:30 : Finished
# 2021-02-22 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:52.758594
# PCT Change Calculated!
# TRENT
# VEDL
# SAIL
# HINDALCO
# JSWSTEEL
# 2021-02-22 09:15:00+05:30 : Finished
# 2021-02-23 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:52.840166
# PCT Change Calculated!
# NMDC
# ONGC
# MPHASIS
# PAGEIND
# UPL
# 2021-02-23 09:15:00+05:30 : Finished
# 2021-02-24 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:52.652996
# PCT Change Calculated!
# ABFRL
# L&TFH
# BANKBARODA
# APOLLOTYRE
# BANDHANBNK
# 2021-02-24 09:15:00+05:30 : Finished
# 2021-02-25 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:55.337155
# PCT Change Calculated!
# BHEL
# PEL
# MANAPPURAM
# MUTHOOTFIN
# HAVELLS
# 2021-02-25 09:15:00+05:30 : Finished
# 2021-02-26 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:06.481865
# PCT Change Calculated!
# NAVINFLUOR
# IRCTC
# SAIL
# BHEL
# GRANULES
# 2021-02-26 09:15:00+05:30 : Finished
# 2021-02-27 09:15:00+05:30 : Started
# 2021-02-27 09:15:00+05:30 : Finished
# 2021-02-28 09:15:00+05:30 : Started
# 2021-02-28 09:15:00+05:30 : Finished
# 2021-03-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:10.617214
# PCT Change Calculated!
# ABFRL
# GUJGASLTD
# NMDC
# ASTRAL
# OFSS
# 2021-03-01 09:15:00+05:30 : Finished
# 2021-03-02 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04
09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.292302
# PCT Change Calculated!
# IEX
# INDUSTOWER
# PIIND
# UBL
# ASTRAL
# 2021-03-19 09:15:00+05:30 : Finished
# 2021-03-20 09:15:00+05:30 : Started
# 2021-03-20 09:15:00+05:30 : Finished
# 2021-03-21 09:15:00+05:30 : Started
# 2021-03-21 09:15:00+05:30 : Finished
# 2021-03-22 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.043415
# PCT Change Calculated!
# CANBK
# ACC
# ADANIENT
# IDEA
# LTI
# 2021-03-22 09:15:00+05:30 : Finished
# 2021-03-23 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.116264
# PCT Change Calculated!
# ADANIENT
# DEEPAKNTR
# MFSL
# ADANIPORTS
# NATIONALUM
# 2021-03-23 09:15:00+05:30 : Finished
# 2021-03-24 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:25.221436
# PCT Change Calculated!
# IPCALAB
# DIXON
# INDIAMART
# GUJGASLTD
# ASIANPAINT
# 2021-03-24 09:15:00+05:30 : Finished
# 2021-03-25 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.257005
# PCT Change Calculated!
# EXIDEIND
# GAIL
# ALKEM
# JSWSTEEL
# SAIL
# 2021-03-25 09:15:00+05:30 : Finished
# 2021-03-26 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:09.775201
# PCT Change Calculated!
# BEL
# BAJAJFINSV
# TATASTEEL
# SRTRANSFIN
# M&MFIN
# 2021-03-26 09:15:00+05:30 : Finished
# 2021-03-27 09:15:00+05:30 : Started
# 2021-03-27 09:15:00+05:30 : Finished
# 2021-03-28 09:15:00+05:30 : Started
# 2021-03-28 09:15:00+05:30 : Finished
# 2021-03-29 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:03.808423
# PCT Change Calculated!
# NAVINFLUOR
# STAR
# IDFCFIRSTB
# NTPC
# SUNTV
# 2021-03-29 09:15:00+05:30 : Finished
# 2021-03-30 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.403996
# PCT Change Calculated!
# NAVINFLUOR
# STAR
# IDFCFIRSTB
# NTPC
# SUNTV
# 2021-03-30 09:15:00+05:30 : Finished
# 2021-03-31 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:36.069194
# PCT Change Calculated!
# IDEA
# NAVINFLUOR
# CONCOR
# MPHASIS
# DLF
# 2021-03-31 09:15:00+05:30 : Finished
# 2021-04-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:05:14.744871
# PCT Change Calculated!
# SRF
# JSWSTEEL
# JINDALSTEL
# AARTIIND
# HINDALCO
# 2021-04-01 09:15:00+05:30 : Finished
# 2021-04-02 09:15:00+05:30 : Started
# Today is a Market Holiday
# 2021-04-03 09:15:00+05:30 : Started
# 2021-04-03 09:15:00+05:30 : Finished
# 2021-04-04 09:15:00+05:30 : Started
# 2021-04-04 09:15:00+05:30 : Finished
# 2021-04-05 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:49.306326
# PCT Change Calculated!
# LALPATHLAB
# METROPOLIS
# NAUKRI
# SHREECEM
# APOLLOHOSP
# 2021-04-05 09:15:00+05:30 : Finished
# 2021-04-06 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.844593
# PCT Change Calculated!
# NAVINFLUOR
# GRANULES
# DEEPAKNTR
# BHEL
# ASIANPAINT
# 2021-04-06 09:15:00+05:30 : Finished
# 2021-04-07 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.141652
# PCT Change Calculated!
# TRENT
# VOLTAS
# CONCOR
# NAUKRI
# ICICIGI
# 2021-04-07 09:15:00+05:30 : Finished
# 2021-04-08 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22
09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.642548
# PCT Change Calculated!
# HINDALCO
# NATIONALUM
# ABFRL
# POLYCAB
# DEEPAKNTR
# 2021-04-27 09:15:00+05:30 : Finished
# 2021-04-28 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.886025
# PCT Change Calculated!
# TVSMOTOR
# MOTHERSUMI
# NAVINFLUOR
# EICHERMOT
# INDUSINDBK
# 2021-04-28 09:15:00+05:30 : Finished
# 2021-04-29 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.534229
# PCT Change Calculated!
# JSWSTEEL
# TATASTEEL
# AUROPHARMA
# GLENMARK
# JUBLFOOD
# 2021-04-29 09:15:00+05:30 : Finished
# 2021-04-30 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.557900
# PCT Change Calculated!
# CONCOR
# ONGC
# GAIL
# RAMCOCEM
# SUNTV
# 2021-04-30 09:15:00+05:30 : Finished
# 2021-05-01 09:15:00+05:30 : Started
# 2021-05-01 09:15:00+05:30 : Finished
# 2021-05-02 09:15:00+05:30 : Started
# 2021-05-02 09:15:00+05:30 : Finished
# 2021-05-03 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:23.888123
# PCT Change Calculated!
# MARICO
# SAIL
# SBILIFE
# BHEL
# ADANIENT
# 2021-05-03 09:15:00+05:30 : Finished
# Wall time: 4h 18min 10s

# %%
############### To Create the csv file ####### DO NOT RUN if you already have csv file it'll overwrite the file ###################

# %%
#Mention the starting date of the data
current_date = date(2021,5,3)
current_date = pd.Timestamp(current_date, tz =19800)
Daily_pct_change = pd.DataFrame()
#todays_date = dt.datetime.now().date()
todays_date  = date(2021,9,23)
pct_change = {}
start = dt.datetime.now()
print(str(current_date) + " : Started")
for ticker in Tickers:
    daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [1])
    daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
    daily_data = daily_data.reset_index(drop = True)
    if(daily_data.empty == True):
        continue
    change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 60)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
    pct_change[ticker] = change_value
    #rint(change_value)

top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
change = pd.DataFrame()
change["Tickers"] = top_gainers.keys()
change["PCT_Change"] = top_gainers.values()
gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
ad_ratio    = gain_number/loss_number
end = dt.datetime.now() - start
print("Time Required to calculate pct change: " + str(end)) 
print("PCT Change Calculated!")
for i in range(5):
    print(change["Tickers"][i])
    
new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
Daily_pct_change.to_csv("Day_Wise_Stats_2021.csv")

date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
#date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
date_data = date_data.reset_index(drop = True)
date_data = date_data[:76]
print(str(current_date) + " : Finished") 
current_date = date_data.date.iloc[-1]
# Out:
# 2021-05-03 00:00:00+05:30 : Started
# Time Required to calculate pct change: 0:03:22.121451
# PCT Change Calculated!
# MARICO
# SAIL
# SBILIFE
# BHEL
# ADANIENT
# 2021-05-03 00:00:00+05:30 : Finished

# %%
import pandas as pd
import numpy as np
import time as TIME
import datetime as dt
from datetime import date
from datetime import timedelta
import math
import os

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('fno_stocks.xlsx', header= 1)
Tickers = (df["Symbol"])
Tickers = Tickers.astype(str)

Tickers = Tickers.drop(Tickers[Tickers.values == "BANKNIFTY"].index.values[0], axis =0)
Tickers = Tickers.drop(Tickers[Tickers.values == "NIFTY"].index.values[0], axis =0)
Tickers = Tickers.reset_index(drop = True)
Tickers
# Out:
# 0            IDEA
# 1      COROMANDEL
# 2            ZEEL
# 3       NESTLEIND
# 4        ASHOKLEY
#           ...
# 167    APOLLOHOSP
# 168        INDIGO
# 169    CANFINHOME
# 170    ICICIPRULI
# 171       SBILIFE
# Name: Symbol, Length: 172, dtype: object

# %%
# %%time
weekDays = ("Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday")
Daily_pct_change = pd.DataFrame()
current_date = date(2017,1,1)
current_date = pd.Timestamp(current_date, tz =19800)
#todays_date = dt.datetime.now().date()
todays_date  = date(2019,7,1)
flag = 0
#Loop from start date till today
while(current_date.date() < todays_date):
    #Calculating daily pct change for all stocks till 10 Am
    
    start = dt.datetime.now()
    pct_change = {}
    Daily_pct_change = pd.read_csv("Day_Wise_Stats_2019.csv", index_col = 0,  parse_dates = [2])
    if(flag==0):
        current_date = Daily_pct_change.Date.iloc[-1] + timedelta(days =1)
        flag = 1
        if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
                
    if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
            print(str(current_date) + " : Started")
            print(str(current_date) + " : Finished") 
            current_date = current_date + timedelta(days =1)
            if(weekDays[current_date.weekday()] == "Saturday" or weekDays[current_date.weekday()] == "Sunday"):
                print(str(current_date) + " : Started")
                print(str(current_date) + " : Finished") 
                current_date = current_date + timedelta(days =1)
    
    print(str(current_date) + " : Started")
    for ticker in Tickers:
        #print(ticker)
        daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [1])
        daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
        daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
        daily_data = daily_data.reset_index(drop = True)
        #print(ticker)
        if(daily_data.empty == True):
            continue
        change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 65)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
        pct_change[ticker] = change_value
    
    if(bool(pct_change) == False):
        print("Today is a Market Holiday")
        current_date = current_date + timedelta(days =1)
        continue
    
    top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
    change = pd.DataFrame()
    change["Tickers"] = top_gainers.keys()
    change["PCT_Change"] = top_gainers.values()
    if(change.empty == True):
        print(str(current_date) + " : Finished") 
        continue
        
    gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
    loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
    ad_ratio    = gain_number/loss_number
    end = dt.datetime.now() - start
    print("Time Required to calculate pct change: " + str(end)) 
    print("PCT Change Calculated!")
    for i in range(5):
        print(change["Tickers"][i])
    new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
    Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
    Daily_pct_change.to_csv("Day_Wise_Stats_2019.csv")
    
    #date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
    ##date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    #date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
    #index = date_data[date_data.date <= current_date + timedelta(minutes  = 370)].index[-1]
    #date_data = date_data[:index + 2]
    ##date_data = date_data.reset_index(drop = True)
    print(str(current_date) + " : Finished")
    current_date = current_date + timedelta(days =1)
# Out:
# 2019-06-07 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.591812
# PCT Change Calculated!
# ASTRAL
# VOLTAS
# PEL
# GODREJPROP
# GUJGASLTD
# 2019-06-07 09:15:00+05:30 : Finished
# 2019-06-08 09:15:00+05:30 : Started
# 2019-06-08 09:15:00+05:30 : Finished
# 2019-06-09 09:15:00+05:30 : Started
# 2019-06-09 09:15:00+05:30 : Finished
# 2019-06-10 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.961370
# PCT Change Calculated!
# MUTHOOTFIN
# BATAINDIA
# INDUSTOWER
# MOTHERSUMI
# MANAPPURAM
# 2019-06-10 09:15:00+05:30 : Finished
# 2019-06-11 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.221967
# PCT Change Calculated!
# ZEEL
# BHEL
# NAVINFLUOR
# PIIND
# TATAMOTORS
# 2019-06-11 09:15:00+05:30 : Finished
# 2019-06-12 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.670296
# PCT Change Calculated!
# JINDALSTEL
# ADANIENT
# SUNPHARMA
# MOTHERSUMI
# TATASTEEL
# 2019-06-12 09:15:00+05:30 : Finished
# 2019-06-13 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:13.432100
# PCT Change Calculated!
# IBULHSGFIN
# GODREJPROP
# PIIND
# IPCALAB
# LALPATHLAB
# 2019-06-13 09:15:00+05:30 : Finished
# 2019-06-14 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.772766
# PCT Change Calculated!
# ASTRAL
# SRTRANSFIN
# MANAPPURAM
# UBL
# LT
# 2019-06-14 09:15:00+05:30 : Finished
# 2019-06-15 09:15:00+05:30 : Started
# 2019-06-15 09:15:00+05:30 : Finished
# 2019-06-16 09:15:00+05:30 : Started
# 2019-06-16 09:15:00+05:30 : Finished
# 2019-06-17 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.211073
# PCT Change Calculated!
# NAVINFLUOR
# APOLLOTYRE
# MOTHERSUMI
# IBULHSGFIN
# MPHASIS
# 2019-06-17 09:15:00+05:30 : Finished
# 2019-06-18 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.899079
# PCT Change Calculated!
# SRF
# PVR
# ZEEL
# GLENMARK
# GUJGASLTD
# 2019-06-18 09:15:00+05:30 : Finished
# 2019-06-19 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.394693
# PCT Change Calculated!
# GRANULES
# GODREJPROP
# ICICIGI
# EICHERMOT
# SIEMENS
# 2019-06-19 09:15:00+05:30 : Finished
# 2019-06-20 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.192370
# PCT Change Calculated!
# PEL
# IBULHSGFIN
# INDUSINDBK
# SHREECEM
# LALPATHLAB
# 2019-06-20 09:15:00+05:30 : Finished
# 2019-06-21 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.955267
# PCT Change Calculated!
# IDEA
# PEL
# LALPATHLAB
# UPL
# APOLLOTYRE
# 2019-06-21 09:15:00+05:30 : Finished
# 2019-06-22 09:15:00+05:30 : Started
# 2019-06-22 09:15:00+05:30 : Finished
# 2019-06-23 09:15:00+05:30 : Started
# 2019-06-23 09:15:00+05:30 : Finished
# 2019-06-24 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.557476
# PCT Change Calculated!
# TRENT
# CUMMINSIND
# UPL
# ADANIENT
# GRANULES
# 2019-06-24 09:15:00+05:30 : Finished
# 2019-06-25 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.222675
# PCT Change Calculated!
# TORNTPOWER
# JSWSTEEL
# MANAPPURAM
# APOLLOTYRE
# INDHOTEL
# 2019-06-25 09:15:00+05:30 : Finished
# 2019-06-26 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.877304
# PCT Change Calculated!
# CADILAHC
# POWERGRID
# DLF
# AUROPHARMA
# TATAPOWER
# 2019-06-26 09:15:00+05:30 : Finished
# 2019-06-27 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:12.829762
# PCT Change Calculated!
# GODREJPROP
# IDEA
# MANAPPURAM
# MOTHERSUMI
# HDFCAMC
# 2019-06-27 09:15:00+05:30 : Finished
# 2019-06-28 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:13.680886
# PCT Change Calculated!
# RECLTD
# CANBK
# HDFCLIFE
# HAL
# PFC
# 2019-06-28 09:15:00+05:30 : Finished
# 2019-06-29 09:15:00+05:30 : Started
# 2019-06-29 09:15:00+05:30 : Finished
# 2019-06-30 09:15:00+05:30 : Started
# 2019-06-30 09:15:00+05:30 : Finished
# 2019-07-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:03:11.518834
# PCT Change Calculated!
# GODREJPROP
# IGL
# BALKRISIND
# TORNTPOWER
# STAR
# 2019-07-01 09:15:00+05:30 : Finished
# Wall time: 54min 29s

# %%
############ To Create the csv file ####### DO NOT RUN if you already have csv file it'll overwrite the file ###################

# %%
#Mention the starting date of the data
current_date = date(2019,7,1)
current_date = pd.Timestamp(current_date, tz =19800) + timedelta(minutes = 555)
Daily_pct_change = pd.DataFrame()
#todays_date = dt.datetime.now().date()
todays_date  = date(2021,9,23)
pct_change = {}
start = dt.datetime.now()
print(str(current_date) + " : Started")
for ticker in Tickers:
    daily_data = pd.read_csv("Historical_Data/" + ticker + ".csv", index_col = 0, parse_dates = [1])
    daily_data = daily_data[daily_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
    daily_data = daily_data[daily_data.date >= pd.Timestamp(current_date)]
    daily_data = daily_data.reset_index(drop = True)
    if(daily_data.empty == True):
        continue
    change_value = (daily_data[daily_data["date"] == daily_data["date"].iloc[0] + timedelta(minutes = 60)].close.values[0] - daily_data.close[0])/daily_data.close[0] 
    pct_change[ticker] = change_value
    #rint(change_value)

top_gainers = dict(sorted(pct_change.items(), key=lambda x: x[1], reverse=True))
change = pd.DataFrame()
change["Tickers"] = top_gainers.keys()
change["PCT_Change"] = top_gainers.values()
gain_number = change[change["PCT_Change"] > 0].shape[0] + 1 
loss_number = change[change["PCT_Change"] <= 0].shape[0] + 1
ad_ratio    = gain_number/loss_number
end = dt.datetime.now() - start
print("Time Required to calculate pct change: " + str(end)) 
print("PCT Change Calculated!")
for i in range(5):
    print(change["Tickers"][i])
    
new_row = {"Date": current_date, "Stock1": change["Tickers"][0], "Stock2" : change["Tickers"][1], "Stock3": change["Tickers"][2], "Stock4": change["Tickers"][3],"Stock5": change["Tickers"][4] , "AD_Ratio":ad_ratio }
Daily_pct_change = Daily_pct_change.append(new_row, ignore_index = True )
Daily_pct_change.to_csv("Day_Wise_Stats_2019.csv")

date_data = pd.read_csv("Historical_Data/" + change["Tickers"][0] + ".csv", index_col = 0, parse_dates = [1])
#date_data = date_data[date_data.date <= pd.Timestamp(current_date) + timedelta(days =1, minutes = 555)]
date_data = date_data[date_data.date >= pd.Timestamp(current_date)]
date_data = date_data.reset_index(drop = True)
date_data = date_data[:76]
print(str(current_date) + " : Finished") 
current_date = date_data.date.iloc[-1]
# Out:
# 2019-07-01 09:15:00+05:30 : Started
# Time Required to calculate pct change: 0:04:38.491818
# PCT Change Calculated!
# GODREJPROP
# TORNTPOWER
# IGL
# STAR
# BALKRISIND
# 2019-07-01 09:15:00+05:30 : Finished
